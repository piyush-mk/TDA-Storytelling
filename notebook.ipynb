# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd=pd.read_excel("Dataset/dataset.xlsx")

# %%
pd.head()
# Out:
#    Epic-1  Satirical-1  Lyric-Rom-1  Epic-2  Didactic-1  Idyllic-1  \
# 0       2            9            3       2           8          9
# 1       2           13            5       2           5          6
# 2      13            2            2      10           2          2
# 3      13            5            8       2           2          6
# 4      13            6            5       1           2          2
#
#    Satirical-2  Lyric-Sad-1  Didactic-2  Idyllic-2  Lyric-Sad-2  Lyric-Rom-2  \
# 0           13            3           6          3            1            2
# 1            5            6           6          9            2            2
# 2            2            2           6          9            8            7
# 3            3            9           7          2           12            3
# 4            5            9           2          9           10            2
#
#    Gender  Age
# 0       1   21
# 1       1   22
# 2       1   21
# 3       1   21
# 4       1   20
